# %% [markdown]
# <a href="https://colab.research.google.com/github/tkazusa/TGSSaltIdentificationChallenge/blob/master/TGSSalt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls drive/My\ Drive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# 'Colab Notebooks'		   RiskTable.xlsx.gsheet
#  insurance14-15.pdf		   src
# 'NakataFes Opening Talk.gslides'  'Untitled spreadsheet.gsheet'
#  pictures			   UserDataAnalysis.pptx
#  Proposal_Figures.pptx		   Variables_B2Capp.xlsx
# 'Proposal tables.xlsx'		   Variables_B2Capp.xlsx.gsheet
#  RiskTable.xlsx

# %%
# !pip install -q keras

# %%
from keras.layers import Input, MaxPooling2D, UpSampling2D, BatchNormalization, Conv2D, add, concatenate
from keras.layers.core import Activation, Reshape
from keras.models import Model
from keras.callbacks import ModelCheckpoint, TensorBoard, CSVLogger
from keras import backend as K
from keras import optimizers
from keras.layers.advanced_activations import PReLU

K.set_image_dim_ordering('tf')
channel_axis = 3
# Out:
# Using TensorFlow backend.

# %%
# !unzip drive/My\ Drive/Colab\ Notebooks/all.zip -d drive/My\ Drive/Colab\ Notebooks/
# Out:
# Archive:  drive/My Drive/Colab Notebooks/all.zip
#   inflating: drive/My Drive/Colab Notebooks/depths.csv
#   inflating: drive/My Drive/Colab Notebooks/train.zip
#   inflating: drive/My Drive/Colab Notebooks/sample_submission.csv
#   inflating: drive/My Drive/Colab Notebooks/test.zip
#   inflating: drive/My Drive/Colab Notebooks/train.csv

# %%
# !unzip drive/My\ Drive/Colab\ Notebooks/train.zip -d drive/My\ Drive/Colab\ Notebooks/
# !unzip drive/My\ Drive/Colab\ Notebooks/test.zip -d drive/My\ Drive/Colab\ Notebooks/
# Out:
# Archive:  drive/My Drive/Colab Notebooks/train.zip
#    creating: drive/My Drive/Colab Notebooks/images/
#    creating: drive/My Drive/Colab Notebooks/masks/
#   inflating: drive/My Drive/Colab Notebooks/images/8d08955cdf.png
#   inflating: drive/My Drive/Colab Notebooks/images/e045664b46.png
#   inflating: drive/My Drive/Colab Notebooks/images/4989c6509e.png
#   inflating: drive/My Drive/Colab Notebooks/images/fff4eb4941.png
#   inflating: drive/My Drive/Colab Notebooks/images/3a310860a3.png
#   inflating: drive/My Drive/Colab Notebooks/images/7a696bb878.png
#   inflating: drive/My Drive/Colab Notebooks/images/8d3ee9356b.png
#   inflating: drive/My Drive/Colab Notebooks/images/213e0a9f7b.png
#   inflating: drive/My Drive/Colab Notebooks/images/78f17697f2.png
#   inflating: drive/My Drive/Colab Notebooks/images/bd20d18369.png
#   inflating: drive/My Drive/Colab Notebooks/images/de08c5a3b7.png
#   inflating: drive/My Drive/Colab Notebooks/images/f06ef6c8b7.png
# ...
